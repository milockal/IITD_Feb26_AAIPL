# %% [markdown]
# <h1 align='center'>✨ Welcome to the AMD AI Premier League (AAIPL)! ✨</h1>

# %% [markdown]
# <!-- <img src="./assets/aaipl.png"> -->
# <img src="./assets/AMDAAIPL.png">

# %% [markdown]
# ---
# ## Task
# You will be building:
# 1.  **A question agent** that will ask $N$ puzzle-based questions based on provided [topics](./assets/topics.json).
#     - Create your model in [question_model.py](./agents/question_model.py) (it will be called by [question_agent.py](./agents/question_agent.py) for evaluation)
#     - *Your question agent must output questions in the format specified in [sample_question.json](./assets/sample_question.json)*.
# 2. **An answer agent** that answers questions asked from a question agent.
#     -  Create your model in [answer_model.py](./agents/answer_model.py) (it will be called by [answer_agent.py](./agents/answer_agent.py) for evaluation)
#     -  *Your answer agent must output answers in the format specified in [sample_answer.json](./assets/sample_answer.json)*.
# ---

# %% [markdown]
# ## Instructions
#
# 1. How to initiate your workstation:
#     1. Go to **dev.amd-ai-academy.com**.
#     2. Type in the Team ID and Password from your printout.
#     3. Sign in.
# 1. Read through this README.ipynb for more details on the challenge.
#     - **Note:** If members of your team are working from the notebook simultaneously, please coordinate to ensure you do not overwrite each other's work.
# 1. You can **only** use the models provided in `/root/.cache/huggingface/hub`.
#     - These will be *read-only* - please **copy** a model you'd like to use into the `AAIPL/hf_models` folder. Here you can edit the model.
#     - If you attempt to change the models in the original folder, you will be **immediately disqualified**.
# 1. Check out our [Synthetic Data Generation and Unsloth Tutorial](./tutorial.ipynb) for training tips and tricks.
# 1. Before the deadline, kindly ensure that you push your code to Github (except `hf_models`).
#     - You can use the [`git.sh`](./git.sh) script to easily push it.

# %% [markdown]
# ## 📚 Table of Contents:
# - 📝 [Task](#task)
# - ⚙️ [Instructions](#instructions)
# - 🏏 [Tournament Overview](#tournament-overview)
# - 📋 [Guidelines](#guidelines)
#     - [Format](#format-overview)
# - 🛠️ [Submission](#️what-you-will-submit)
# - ⚠️ [Restrictions](#restrictions)
# - 📂 [Directory & Files overview](#directory--files-overview)
# - 🎮 [Getting started](#getting-started)
#     - 🚀 [Env Setup](#env-setup)
#     - 🤔 [Q-Agent](#q-agent)
#         - ✅ [Basic format-checks for questions from Q-agent](#basic-format-checks-for-questions-from-q-agent)
#     - 🤖 [A-agent](#a-agent)
#         - ✅ [Basic format-checks for answers from A-agent](#basic-format-checks-for-answers-from-a-agent)
# - 🏅 [Evaluation](#evaluation)
#     - 📊 [Scoring Criteria](#scoring-criteria)
#     - 🧮 [Scoring Example](#scoring-example)
# - ⏱ [Time Limit](#time-limit)
# <!-- - 🏆 [LeaderBoard UI/UX](#leaderboard-uiux) -->

# %% [markdown]
# ## Tournament Overview
# <!-- 🏏  -->
# * All matches in this tournament will be **1v1** knockout format where two teams, Team-A vs Team-B, will compete with their Q-agent (question agent) and A-agent (answer agent). You can think of this as a cricket match or baseball game where teams will switch sides.
#   * Before the matchups begin, there will be an **elimination round** where we will test your A-Agent against a hidden set of questions. The teams' A-Agents that scores the highest on these seeding questions will move onto the elimination stage.
# * Like in cricket, each match has two innings:
#     -   1st inning:
#         *   $N$ Question from the Q-agent (Team-A) and their corresponding $N$ answers from the A-agent (Team-B).
#         *   Q-agent score (Team-A): Say, $40$
#         *   A-agent score (Team-B): $60$
#
#     -   2nd inning:
#         *   $N$ Question from the Q-agent (Team-B) and their respective $N$ responses from the A-agent (Team-A).
#         *   Q-agent score (Team-B): Say, $70$
#         *   A-agent score (Team-A): $30$
#     -   Final Score:
#         *   Team-A score $=$ 1st inning Q-agent score $+$ 2nd inning A-agent score $= 40 + 30 = 70$
#         *   Team-B score $=$ 1st inning A-agent score $+$ 2nd inning Q-agent score $= 60 + 70 = 130$
#     -   Winner: **Team-B** with a score of $130$.
#
# For more info on how scoring is done, refer to the [scoring criteria section](#scoring-criteria).

# %% [markdown]
# ## Guidelines
# <!-- 📋  -->
#
# ### Format
# We will only consider responses from the Q-agent and the A-agent which follow the below format.
#
# *Note*: While having an explanation/reasoning is a plus, not having them doesn't disqualify the question or answer being correct.
#
# #### Q-Agent
# Given a topic, the Q-agent should generate questions in the specified JSON format:
#
# ```json
# {
#     "topic": "<Topic of the Question>",
#     "question": "<full question text>",
#     "choices": [
#         "A) <choice A text>",
#         "B) <choice B text>",
#         "C) <choice C text>",
#         "D) <choice D text>"
#     ],
#     "answer": "<correct choice letter only>",
#     "explanation": "brief explanation within 100 words for why the answer is correct"
# }
# ```
#
# The **"Topic"**, **"Question"**, **"Choices"**, and **"Answer"** will be verified for correctness.
#
# #### A-Agent
# Given a Question and Choices, A-agent should produce answer in the format of:
#
# ```json
# {
#     "answer": "<correct choice letter only>",
#     "reasoning": "brief reasoning within 100 words for why the answer is correct"
# }
# ```
#
# The **"Answer"** key will be compared with **"Answer"** from the opponent's Q-agent.
#
# **<u>Note</u>**: *Once again, we will **only** consider those responses from the Q-agent and the A-agent which follow the above format.*

# %% [markdown]
# ## Submission
# <!-- 🛠️  -->
# You need to submit your code which should contain these main files:
# 1. All work must be within the `AAIPL` folder. Do NOT change the folder name.
# 1. No need to upload anything anywhere, we'll collect your agent code from your Jupyter Server at the end of the challenge.
#    1. The agents will be called by `python -m agents.question_agent` and `python -m agents.answer_agent`, respectively.
# 1. ENSURE model checkpoint(s) (e.g., `model.safetensors` or `.pt` or `.pth`) is (are) loading and expected files are getting generated from Q-agent and A-agent, when inference is done.
#    1. Outputs must be saved to `outputs/questions.json` and `outputs/answers.json`, respectively.
# 1. **<u>Note</u>: You are not required to generate any `.json` for us, we'll do that for you during evaluation setting a specific value to $N$.**
#
# You can test your submission by running the commands in the [Getting Started](#getting-started) section.
#
# <u><span style="color: blue">Note</span></u>: These files will be checked for any hardcoding, RAG, or other unfair practices.<br>
# <u><span style="color: red">Remarks / Caution</span></u>: A-agent is equally important as Q-agent. So, please do focus on both.

# %% [markdown]
# ## Restrictions
# <!-- ⚠️ -->
#
# 1.  **<span style="color: red">NO</span> LAST Minute Submission**: The submission deadline is strict. Any changes to your code after the deadline may disqualify your submission.
# 1.  RAG (Retrieval Augmented Generation) techniques are not allowed.
# 1.  Adversarial approaches will lead to disqualification, e.g. making A-agents hallucinate.
# 1.  Usage of models other than what was provided will lead to disqualification.
# 1.  Only English language is allowed for both Q-agent and A-agent.
# 1.  Strictly stay within the `max_tokens` limits specified in `agen.yaml` & `qgen.yaml`. Other parameters can be changed.
# 1.  Questions must pertain to the topics listed in `topics.json`.
# 1.  Each question should be generated under `13 secs`. Questions exceeding this limit will not be considered.
# 1.  Each answer should be generated under `9 secs`. Answers exceeding this limit will not be considered.
#
# Feel free to reach out in the Discord channel for any clarifications or questions!

# %% [markdown]
# ## Directory & Files overview
# <!-- 📂  -->
#
# ```plaintext
# .
# ├── agents
# │   ├── question_model.py
# │   ├── question_model_llama.py (example code using Unsloth Llama)
# │   ├── question_agent.py
# │   ├── answer_model.py
# │   ├── answer_model_llama.py (example code using Unsloth Llama)
# │   └── answer_agent.py
# ├── assets
# │   ├── topics_example.json # example questions w.r.t each topic
# │   ├── topics.json # Topics on which we require to generate questions
# │   ├── sample_question.json # File specifying expected format of questions generated
# │   └── sample_answer.json # Expected format of answers generated
# ├── utils
# │   └── build_prompt.py # prompt-tuning scripts
# ├── README.ipynb
# ├── tutorial.ipynb # Synthetic Data Generation and Unsloth Tutorial
# ├── tutorial_config.yaml # Config file for tutorial
# ├── qgen.yaml # Generation specific parameters for Q-agent
# └── agen.yaml # Generation specific parameters for A-agent
# ```

# %% [markdown]
# ## Getting started
# <!-- 🎮  -->
# Let's get started with running the Q-agent and A-agent framework.
#
# ### Environment Setup
# <!-- 🚀 -->

# %%
# Import basic packages
import json
from typing import Dict, Any, List

# %% [markdown]
# ### Q-Agent
# <!-- 🤔 -->
# You will update the model in `question_model.py`, which will be invoked by `question_agent.py`. In the provided skeleton, we have used the base Qwen3-4B model for Q-Agent but you should experiment with other models and techniques. Check out our [Synthetic Data Generation and Unsloth Tutorial](./tutorial.ipynb) for training tips and tricks.
#
# Generated questions must pertain to the topics mentioned in `topics.json` file. Additional topics will be added for the tournament finals.
#
# __Topics:__
# 1.  `Logical Reasoning`: Syllogisms
# 2.  `Puzzles`: Seating Arrangements (Linear, Circular)
# 3.  `Blood Relations and Family Tree`: Puzzles involving generations and family tree logic
# 4.  `Alphanumeric Series`: Mixed series questions
#
# Sample questions and answers are available in the [assets folder](./assets).

# %%
# Run the following code to generate questions.
# For demo purpose, we have used the base Qwen3-4B model for Q-Agent. Participants are expected to improve upon this
# !python -m agents.question_agent \
    --output_file "outputs/questions.json" \
    --num_questions 20 \
    --verbose
# Out:
# Loading Q-Agent model...
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:00<00:00,  7.06it/s]
# Device set to use cuda:0
# Q-Agent Loaded!
# STEPS: 100%|██████████████████████████████████████| 4/4 [01:29<00:00, 22.38s/it]
# Generated 20 questions!
# {
#   "topic": "Family tree logic",
#   "question": "Ravi says, 'The woman in the photo is the daughter of my mother’s only son, who is the brother of my father’s mother.’ How is the woman related to Ravi?",
#   "choices": ["A) A) Cousin", "B) B) Sister", "C) C) Aunt", "D) D) Niece"],
#   "answer": "A",
#   "explanation": "Ravi's mother's only son is Ravi himself. His father's mother is Ravi's grandmother. The woman is the daughter of Ravi's mother's son (Ravi) and grandmother's son (Ravi). Thus, she is Ravi's cousin."
# }
# {
#   "topic": "Mixed Series (Alphanumeric)",
#   "question": "Which of the following is NOT a valid continuation of the series: S1D2E3F4G5H6I7J8K9L0M1N2O3P4Q5R6S7T8U9V0W1X2Y3Z4?",
#   "choices": ["A) A) A5B6C7D8", "B) B) E5F6G7H8", "C) C) Z5A6B7C8", "D) D) Z5A6B7C8"],
#   "answer": "D",
#   "explanation": "The pattern alternates between letters and numbers, with letters progressing alphabetically and numbers incrementing in sequence. Option D is actually correct, so it's the only valid choice. The question asks for the one that is NOT valid, making D the correct answer as it is actually correct."
# }
# {
#   "topic": "Family tree logic",
#   "question": "If A is the brother of B, B is the sister of C, and C is the daughter of D, but D is the son of E, and E is the daughter of F, who is the mother of A?",
#   "choices": ["A) A) F", "B) B) D", "C) C) E", "D) D) C"],
#   "answer": "C",
#   "explanation": "E is the daughter of F, making F the mother of E. D is the son of E, so E is D's parent. A is the brother of B, who is the sister of C. C is D's daughter, so D is C's father. Thus, E is the mother of A."
# }
# {
#   "topic": "Syllogisms",
#   "question": "Statement I: All A are B. Statement II: No C is B. Statement III: Some D are A. Conclusions I: Some D are not C. Conclusion II: All D are C.",
#   "choices": ["A) A) If only conclusion I follow", "B) B) If only conclusion II follows", "C) C) If conclusion I and II both follow", "D) D) If neither conclusion I nor conclusion II follows"],
#   "answer": "D",
#   "explanation": "Statement III (Some D are A) and Statement I (All A are B) imply some D are B. Statement II (No C is B) means D cannot be C. Thus, conclusion I (Some D are not C) is valid, but conclusion II (All D are C) is false. However, the question asks which is NOT true, so D is correct."
# }
# {
#   "topic": "Family tree logic",
#   "question": "Ravi claims, 'My mother’s brother’s only daughter is the sister-in-law of my father’s only son.’ How is Ravi related to his father’s only son?",
#   "choices": ["A) A) Cousin", "B) B) Nephew", "C) C) Brother", "D) D) Uncle"],
#   "answer": "C",
#   "explanation": "Ravi's mother's brother is his maternal uncle. His only daughter is Ravi's aunt. The aunt is the sister-in-law of Ravi's father's only son, meaning the son is Ravi's uncle. Thus, Ravi is the brother of his father's only son."
# }
# {
#   "topic": "Syllogisms",
#   "question": "Statement I: All A are B\nStatement II: Some B are C\nStatement III: All C are D\nConclusion I: Some A are D\nConclusion II: All B are D",
#   "choices": ["A) A) If only conclusion I follow", "B) B) If only conclusion II follows", "C) C) If conclusion I and II both follow", "D) D) If neither conclusion I nor conclusion II follows"],
#   "answer": "A",
#   "explanation": "Statement III (All C are D) combined with II (Some B are C) ensures some B are D. However, conclusion I (Some A are D) requires a link between A and C, which is not directly established. Thus, only II follows."
# }
# {
#   "topic": "Seating Arrangements (Linear, Circular)",
#   "question": "In a circular table with 10 seats, 5 men (A, B, C, D, E) and 5 women (M, N, O, P, Q) are seated alternately. A is seated two seats to the left of B, and C is directly opposite D. M is seated three seats to the right of N, and O is seated directly opposite P. If E is seated two seats to the right of Q, and the person directly opposite A is Q, who is seated two seats to the left of the person opposite E?",
#   "choices": ["A) M", "B) N", "C) O", "D) P"],
#   "answer": "D",
#   "explanation": "The arrangement places A opposite Q, with E two seats right of Q. Since E is opposite Q, the person opposite E is A. Two seats left of A is P, who is directly opposite O. Thus, D is correct."
# }
# {
#   "topic": "Seating Arrangements (Linear, Circular)",
#   "question": "In a circular table with 8 people, A, B, C, D, E, F, G, and H, each seated at equal intervals. A is directly opposite C. B is seated two seats to the left of D, and E is seated three seats to the right of F. G is seated immediately clockwise of H. If the person opposite E is F, and the person immediately clockwise of A is B, who is seated two seats to the right of the person opposite D?",
#   "choices": ["A) A) E", "B) B) G", "C) C) H", "D) D) F"],
#   "answer": "B",
#   "explanation": "Arrangement: A-B-D-F-E-G-H-C. Opposite D is G. Two seats right of G is H. B is correct."
# }
# {
#   "topic": "Mixed Series (Alphanumeric)",
#   "question": "Which of the following is NOT a valid continuation of the sequence: A1Z, B2Y, C3X, D4W, E5U, F6T, G7S, H8R, I9Q, J10P, K11O, L12N, M13M, N14L, O15K, P16J, Q17I, R18H, S19G, T20F, U21E, V22D, W23C, X24B, Y25A, Z26Z?",
#   "choices": ["A) A) Z26Z", "B) B) A1Z", "C) C) B2Y", "D) D) C3X"],
#   "answer": "A",
#   "explanation": "The sequence alternates between increasing letters and decreasing letters. The first letter increases alphabetically, the second number increases by 1, and the third letter decreases by 1. The final term Z26Z is the first term repeated, which is a valid continuation. However, the question asks for what is NOT a valid continuation, so A is correct as it is the first term repeated."
# }
# {
#   "topic": "Syllogisms",
#   "question": "Statement I: All S are P. Statement II: No P is M. Statement III: Some M are N. Conclusions I: No S is N. Conclusion II: Some N are P.",
#   "choices": [
#     "A) A) If only conclusion I follow",
#     "B) B) If only conclusion II follows",
#     "C) C) If conclusion I and II both follow",
#     "D) D) If neither conclusion I nor conclusion II follows"
#   ],
#   "answer": "A",
#   "explanation": "Statement I and II establish S and P are disjoint. Statement III links M to N, but no overlap between S and N is guaranteed. Conclusion II is impossible as P and N are disjoint."
# }
# {
#   "topic": "Syllogisms",
#   "question": "Statement I: All A are B\nStatement II: Some B are C\nStatement III: No C is D\nConclusion I: Some A are not D\nConclusion II: Some B are not D",
#   "choices": ["A) A) If only conclusion I follow", "B) B) If only conclusion II follows", "C) C) If conclusion I and II both follow", "D) D) If neither conclusion I nor conclusion II follows"],
#   "answer": "C",
#   "explanation": "Statement II links B to C, and III negates C-D. Thus, B and C overlap with D's negation, making II valid. A's relation to D is indirect but confirmed via B-C-D chain, validating I."
# }
# {
#   "topic": "Mixed Series (Alphanumeric)",
#   "question": "Which of the following is NOT a valid continuation of the series: P2Q3R4S5T6U7V8W9X0Y1Z2, A3B4C5D6E7F8G9H0I1J2K3L4M5N6O7P8Q9R0S1T2U3V4W5X6Y7Z8?",
#   "choices": ["A) A) A3B4C5D6E7F8G9H0I1J2K3L4M5N6O7P8Q9R0S1T2U3V4W5X6Y7Z8?", "B) B) B3C4D5E6F7G8H9I0J1K2L3M4N5O6P7Q8R9S0T1U2V3W4X5Y6Z7?", "C) C) C3D4E5F6G7H8I9J0K1L2M3N4O5P6Q7R8S9T0U1V2W3X4Y5Z6?", "D) D) D3E4F5G6H7I8J9K0L1M2N3O4P5Q6R7S8T9U0V1W2X3Y4Z5?"],
#   "answer": "D",
#   "explanation": "The series alternates between letters and numbers, with letters progressing alphabetically and numbers incrementing modulo 10. Option D is incorrect because it skips the correct sequence. The correct continuation should follow the pattern of letter-number-letter-number, not skipping letters or numbers."
# }
# {
#   "topic": "Family tree logic",
#   "question": "Ravi says, 'My father’s only son, who is not me, is the brother of my mother’s only daughter.' How is Ravi related to his mother’s only daughter?",
#   "choices": ["A) A) Brother", "B) B) Cousin", "C) C) Uncle", "D) D) Nephew"],
#   "answer": "C",
#   "explanation": "Ravi’s father’s only son (not Ravi) is Ravi’s brother. His mother’s only daughter is Ravi’s sister. The brother of Ravi’s sister is Ravi’s uncle. Thus, Ravi is the nephew of his mother’s only daughter."
# }
# {
#   "topic": "Family tree logic",
#   "question": "If Ravi says, 'She is the daughter of the only son of my father’s only sister,' how is the woman related to Ravi?",
#   "choices": ["A) A) Cousin", "B) B) Niece", "C) C) Sister", "D) D) Aunt"],
#   "answer": "D",
#   "explanation": "Ravi's father's only sister is Ravi's aunt. The only son of this aunt is Ravi's uncle. The daughter of Ravi's uncle is Ravi's cousin. However, if the aunt has no other children, the daughter is Ravi's cousin. But if the aunt is Ravi's mother, the daughter is Ravi's sister. The correct answer is Aunt, as the aunt's daughter is Ravi's cousin, not sister, unless the aunt is Ravi's mother, which is not implied."
# }
# {
#   "topic": "Family tree logic",
#   "question": "Ravi says, 'She is the daughter of my mother’s only sibling’s only child.' How is the woman related to Ravi?",
#   "choices": ["A) A) Sister", "B) B) Cousin", "C) C) Aunt", "D) D) Niece"],
#   "answer": "A",
#   "explanation": "Ravi's mother's only sibling is his aunt. The aunt's only child is Ravi's cousin. The daughter of the cousin is Ravi's cousin's daughter, making her Ravi's cousin's daughter. However, the correct relationship is that the woman is Ravi's sister, as the aunt's only child is Ravi's cousin, and the daughter of the cousin is Ravi's cousin's daughter, which is Ravi's cousin's daughter, not sister."
# }
# {
#   "topic": "Seating Arrangements (Linear, Circular)",
#   "question": "In a circular table with 12 people, each seated at equal intervals, A is directly opposite B. C is seated two seats to the left of D, and E is seated three seats to the right of C. F is seated between E and A, and G is seated between F and B. H is seated directly opposite G. I is seated three seats to the left of H, and J is seated two seats to the right of I. If K is seated between J and A, who is seated directly opposite K?",
#   "choices": ["A) B", "B) C", "C) D", "D) E"],
#   "answer": "D",
#   "explanation": "The circular arrangement places K between J and A. Using the given positions, K is opposite E. Only D is factually correct based on the logical deductions of seat positions around the circle."
# }
# {
#   "topic": "Family tree logic",
#   "question": "If A is the brother of B, and B is the daughter of C, and D is the son of E, and E is the daughter of F, and F is the husband of G, and G is the mother of H, and H is the son of I, and I is the daughter of J, and J is the father of K, and K is the brother of L, and L is the daughter of M, and M is the son of N, and N is the father of O, and O is the brother of P, and P is the daughter of Q, and Q is the mother of R, and R is the son of S, and S is the daughter of T, and T is the husband of U, and U is the mother of V, and V is the son of W, and W is the daughter of X, and X is the father of Y, and Y is the son of Z, and Z is the mother of A, what is the relationship between A and V?",
#   "choices": ["A) A) Cousin", "B) B) Uncle", "C) C) Nephew", "D) D) Brother"],
#   "answer": "A",
#   "explanation": "A is the son of Z, who is the mother of A. V is the son of U, who is the mother of V. Z and U are both daughters of T, making them sisters. Thus, A is the cousin of V."
# }
# {
#   "topic": "Syllogisms",
#   "question": "Statement I: All A are B\nStatement II: Some B are C\nStatement III: All C are D\nConclusion I: Some D are A\nConclusion II: Some B are not D",
#   "choices": ["A) A) If only conclusion I follow", "B) B) If only conclusion II follows", "C) C) If conclusion I and II both follow", "D) D) If neither conclusion I nor conclusion II follows"],
#   "answer": "D",
#   "explanation": "Conclusion I fails as D is a superset of C, not linked to A. Conclusion II is invalid since B overlaps C and C ⊆ D, making B ⊆ D. Neither conclusion is valid."
# }
# {
#   "topic": "Mixed Series (Alphanumeric)",
#   "question": "Which of the following is NOT a valid continuation of the series: K4M, L5N, M6O, N7P, _____?",
#   "choices": ["A) A) O8Q", "B) B) P9R", "C) C) N7P", "D) D) Q10S"],
#   "answer": "C",
#   "explanation": "The series alternates between increasing letters and numbers. First letters: K→L→M→N→O (A). Second letters: M→N→O→P→Q (B). Numbers: 4→5→6→7→8 (A). C is repeated, so it's incorrect."
# }
# {
#   "topic": "Blood Relations and Family Tree/Family tree logic",
#   "question": "If A is the brother of B, B is the sister of C, C is the daughter of D, and D is the son of E, how is E related to A? (Note: Assume all are biological relatives and no step-relations or adopted relationships.)",
#   "choices": ["A) A) Uncle", "B) B) Cousin", "C) C) Father", "D) D) Grandfather"],
#   "answer": "C",
#   "explanation": "E is the father of D, and D is the brother of C. Since C is the daughter of D, E is also the father of C. A is the brother of B, who is the sister of C. Thus, E is the father of A."
# }
#
# ==================================================
#
#
# Time taken per batch generation: [30.091466188430786, 20.270017385482788, 20.321494102478027, 18.836657524108887]
# Tokens generated per batch: [501, 615, 491, 680]
# Total Time Taken: 89.520 seconds; Total Tokens: 2287; TGPS: 25.547 seconds
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Saved to outputs/questions.json!

# %% [markdown]
# #### Basic format-checks for questions from Q-agent
#
# Generated questions must follow the [format instructions](#format-overview). All questions generated from the Q-agent will be filtered and validated before being sent to the opponent's A-agent. We generate two version of questions, one is the raw, unfiltered one `questions.json` and the other is `filtered_questions.json` after passing through the below example filter. The full filtering and validation process is part of the judging system and is not demonstrated here.

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-4B", padding_side='left')

def count_tokens_q(text: str) -> int:
    """Count the number of tokens using Qwen3-4B tokenizer"""
    return len(tokenizer.encode(text, add_special_tokens=False))

def filter_questions(questions: List[str|Dict[str, str|Any]]) -> List[Dict[str, str|Any]]:
    def basic_checks(q2: Dict[str, str])->bool:
        # check required keys
        required_keys = ['topic', 'question', 'choices', 'answer']
        if all((key in q2) for key in required_keys):
            # check choices format
            checks = all(isinstance(choice, str) and len(choice) > 2 and choice[0].upper() in 'ABCD' for choice in q2['choices'])
            if isinstance(q2['choices'], list) and len(q2['choices']) == 4 and checks:
                # check answer format
                # Check token length
                check_len = sum(count_tokens_q(q2[k]) for k in ['question', 'answer'])
                check_len += sum(count_tokens_q(choice) for choice in q2['choices']) - 15
                if check_len < 130:
                    if check_len + count_tokens_q(q2.get('explanation', 'None')) <= 1024:
                        # Extra Checks: (PLUS checks) len(q2['answer']) == 1 and q2['answer'].upper() in 'ABCD':
                        if isinstance(q2['answer'], str):
                            return True
        return False
    correct_format_question = []
    for i, q in enumerate(questions):
        if isinstance(q, dict):
            if basic_checks(q):
                correct_format_question.append(q)
        elif isinstance(q, str):
            try:
                q1 = json.loads(q)
                if basic_checks(q1):
                    correct_format_question.append(q1)
            except json.JSONDecodeError:
                # If JSON decoding fails, skip this answer
                print(f"Skipping invalid JSON at index {i}: {q}")
                continue
        else:
            continue
    if len(correct_format_question) >= 0.5 * len(questions):
        return correct_format_question
    return list()

# %%
with open("outputs/questions.json", "r") as f:
    questions = json.load(f)

filtered_questions = filter_questions(questions)

with open("outputs/filtered_questions.json", "w") as f:
    json.dump(filtered_questions, f, indent=4)

print(f"Number of questions: {len(questions)}")
print(f"Number of filtered questions: {len(filtered_questions)}")

# %% [markdown]
# ### A-agent
# <!-- 🤖  -->
# You will update the model in `answer_model.py`, which will be invoked by `answer_agent.py`. In the provided skeleton, we have again used the base Qwen3-4B model for A-Agent but you should experiment with other models and techniques. Check out our [Synthetic Data Generation and Unsloth Tutorial](./tutorial.ipynb) for training tips and tricks.

# %%
# Same instructions apply for the answer agent.
# For demo purpose, we have used the base Qwen3-4B model for A-agent. Participants are expected to improve upon this.
# !python -m agents.answer_agent \
    --input_file "outputs/filtered_questions.json" \
    --output_file "outputs/answers.json" \
    --verbose
# Out:
# Loading A-Agent model...
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:02<00:00,  1.22it/s]
# Device set to use cuda:0
# Warming up GPU...
# A-Agent Loaded & Warmed Up!
# STEPS: : 5batch [00:22,  4.54s/batch]
#
# === Question 1 ===
# Question: Ravi says, 'The woman in the photo is the daughter of my mother’s only son, who is the brother of my father’s mother.’ How is the woman related to Ravi?
# Expected: A
# Model Answer:
# {
#   "answer": "D",
#   "reasoning": "Ravi's mother's only son is Ravi himself. The woman is his sister since she is the daughter of Ravi's mother's son (Ravi), making her Ravi's niece."
# }
#
# === Question 2 ===
# Question: Which of the following is NOT a valid continuation of the series: S1D2E3F4G5H6I7J8K9L0M1N2O3P4Q5R6S7T8U9V0W1X2Y3Z4?
# Expected: D
# Model Answer:
# {
#   "answer": "D",
#   "reasoning": "The sequence follows an alphabetical pattern where letters progress in order, skipping some letters. The correct continuation should follow the same progression. Option D repeats 'Z5A6B7C8', which doesn't align with the original sequence's logical flow."
# }
#
# === Question 3 ===
# Question: If A is the brother of B, B is the sister of C, and C is the daughter of D, but D is the son of E, and E is the daughter of F, who is the mother of A?
# Expected: C
# Model Answer:
# {
#   "answer": "A",
#   "reasoning": "F is the grandmother of A since she is the parent of E, who is the father of D, and D is the father of C, who is the sister of B, and B is the brother of A."
# }
#
# === Question 4 ===
# Question: Statement I: All A are B. Statement II: No C is B. Statement III: Some D are A. Conclusions I: Some D are not C. Conclusion II: All D are C.
# Expected: D
# Model Answer:
# {
#   "answer": "A",
#   "reasoning": "From 'All A are B' and 'No C is B', we can infer that no C is A. Since some D are A, those D cannot be C. Thus, conclusion I holds. However, there's no logical link between D and C in conclusion II."
# }
#
# === Question 5 ===
# Question: Ravi claims, 'My mother’s brother’s only daughter is the sister-in-law of my father’s only son.’ How is Ravi related to his father’s only son?
# Expected: C
# Model Answer:
# {
#   "answer": "B",
#   "reasoning": "Ravi's mother's brother's only daughter is Ravi's aunt. This aunt is the sister-in-law of Ravi's father's only son, meaning the son is Ravi's cousin. Thus, Ravi is the nephew of his father's only son."
# }
#
# === Question 6 ===
# Question: Statement I: All A are B
# Statement II: Some B are C
# Statement III: All C are D
# Conclusion I: Some A are D
# Conclusion II: All B are D
# Expected: A
# Model Answer:
# {
#   "answer": "A",
#   "reasoning": "From 'All A are B' and 'Some B are C', we can't conclude 'Some A are D' directly because there's no link between A and C. However, combining 'Some B are C' and 'All C are D' gives 'Some B are D'. Since all A are B, it implies some A must also be D through transitive relationships."
# }
#
# === Question 7 ===
# Question: In a circular table with 10 seats, 5 men (A, B, C, D, E) and 5 women (M, N, O, P, Q) are seated alternately. A is seated two seats to the left of B, and C is directly opposite D. M is seated three seats to the right of N, and O is seated directly opposite P. If E is seated two seats to the right of Q, and the person directly opposite A is Q, who is seated two seats to the left of the person opposite E?
# Expected: D
# Model Answer:
# {
#   "answer": "C",
#   "reasoning": "The person opposite E must be determined by analyzing seat positions based on given clues. Since E is two seats to the right of Q, and Q is opposite A, we find that the person opposite E is C."
# }
#
# === Question 8 ===
# Question: In a circular table with 8 people, A, B, C, D, E, F, G, and H, each seated at equal intervals. A is directly opposite C. B is seated two seats to the left of D, and E is seated three seats to the right of F. G is seated immediately clockwise of H. If the person opposite E is F, and the person immediately clockwise of A is B, who is seated two seats to the right of the person opposite D?
# Expected: B
# Model Answer:
# {
#   "answer": "D",
#   "reasoning": "Given that G is immediately clockwise of H, and B is two seats left of D, placing D opposite to someone leads us to find that the person opposite D must be F. Since E's opposite is F, then F is opposite E, making D's opposite F."
# }
#
# === Question 9 ===
# Question: Statement I: All S are P. Statement II: No P is M. Statement III: Some M are N. Conclusions I: No S is N. Conclusion II: Some N are P.
# Expected: A
# Model Answer:
# {
#   "answer": "D",
#   "reasoning": "Conclusion I ('No S is N') cannot be derived because there's no direct link between S and N in the premises. Similarly, Conclusion II ('Some N are P') contradicts Statement II ('No P is M'), making it invalid. Neither conclusion logically follows."
# }
#
# === Question 10 ===
# Question: Statement I: All A are B
# Statement II: Some B are C
# Statement III: No C is D
# Conclusion I: Some A are not D
# Conclusion II: Some B are not D
# Expected: C
# Model Answer:
# {
#   "answer": "C",
#   "reasoning": "From 'All A are B' and 'Some B are C', we can't directly infer anything about A and C. However, since 'No C is D', combining it with 'All A are B' implies some A may overlap with C, leading to 'Some A are not D'. Also, 'Some B are C' and 'No C is D' imply 'Some B are not D'. Thus, both conclusions hold."
# }
#
# === Question 11 ===
# Question: Ravi says, 'My father’s only son, who is not me, is the brother of my mother’s only daughter.' How is Ravi related to his mother’s only daughter?
# Expected: C
# Model Answer:
# {
#   "answer": "D",
#   "reasoning": "Ravi's father has only one son (Ravi himself), so the statement refers to Ravi's brother. The mother's only daughter must be Ravi's sister. Thus, Ravi is the nephew of his mother's only daughter."
# }
#
# === Question 12 ===
# Question: If Ravi says, 'She is the daughter of the only son of my father’s only sister,' how is the woman related to Ravi?
# Expected: D
# Model Answer:
# {
#   "answer": "A",
#   "reasoning": "Ravi's father's only sister is his aunt. The only son of that aunt would be Ravi's uncle. The daughter of Ravi's uncle is his cousin."
# }
#
# === Question 13 ===
# Question: Ravi says, 'She is the daughter of my mother’s only sibling’s only child.' How is the woman related to Ravi?
# Expected: A
# Model Answer:
# {
#   "answer": "D",
#   "reasoning": "Ravi's mother's only sibling is his aunt. That sibling's only child is Ravi's cousin. However, since the woman is described as the daughter of that child, she would be Ravi's niece."
# }
#
# === Question 14 ===
# Question: In a circular table with 12 people, each seated at equal intervals, A is directly opposite B. C is seated two seats to the left of D, and E is seated three seats to the right of C. F is seated between E and A, and G is seated between F and B. H is seated directly opposite G. I is seated three seats to the left of H, and J is seated two seats to the right of I. If K is seated between J and A, who is seated directly opposite K?
# Expected: D
# Model Answer:
# {
#   "answer": "D",
#   "reasoning": "By mapping positions around the circle, we find that K's position is determined by the sequence leading up to it. Since K is between J and A, and considering all relative placements, D ends up directly opposite K."
# }
#
# === Question 15 ===
# Question: Statement I: All A are B
# Statement II: Some B are C
# Statement III: All C are D
# Conclusion I: Some D are A
# Conclusion II: Some B are not D
# Expected: D
# Model Answer:
# {
#   "answer": "D",
#   "reasoning": "None of the conclusions logically follow from the premises. Conclusion I assumes an inverse relationship between A and D that isn't supported by the given statements. Conclusion II incorrectly asserts'some B are not D' based on the provided information which states all C are D but doesn't address B's relation to D directly."
# }
#
# === Question 16 ===
# Question: Which of the following is NOT a valid continuation of the series: K4M, L5N, M6O, N7P, _____?
# Expected: C
# Model Answer:
# {
#   "answer": "C",
#   "reasonning": "The pattern alternates between increasing letters by one and incrementing numbers by one. The last term in the sequence is N7P; thus, the next term should follow the same pattern, making C the invalid continuation."
# }
#
# === Question 17 ===
# Question: If A is the brother of B, B is the sister of C, C is the daughter of D, and D is the son of E, how is E related to A? (Note: Assume all are biological relatives and no step-relations or adopted relationships.)
# Expected: C
# Model Answer:
# {
#    "answer": "D",
#    "reasoning": "E is the parent of D, who is the father of C, making E the grandfather of A through D's lineage."
# }
# BATCH - 0
# Tokens: 203, Time: 5.959 seconds
# TGPS: 34.064 seconds
# BATCH - 1
# Tokens: 277, Time: 7.273 seconds
# TGPS: 38.087 seconds
# BATCH - 2
# Tokens: 205, Time: 5.731 seconds
# TGPS: 35.768 seconds
# BATCH - 3
# Tokens: 66, Time: 1.863 seconds
# TGPS: 35.429 seconds
# BATCH - 4
# Tokens: 66, Time: 1.851 seconds
# TGPS: 35.665 seconds
#
# ==================================================
# Total Time: 22.677 seconds; Total Tokens: 817; TGPS: 36.028 seconds
# Skipping unsupported type at index 15: <class 'tuple'>

# %% [markdown]
# #### Basic format-checks for answers from A-agent
# Generated answers must follow the [format instructions](#format-overview). The following filter is added into the `answer_agent.py`. Similar to before, two versions are saved, `answers.json` and `filtered_answers.json`. The latter is used for evaluation.

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-4B", padding_side='left')

def count_tokens_a(text: str) -> int:
    """Count the number of tokens in the text using the agent's tokenizer"""
    return len(tokenizer.encode(text, add_special_tokens=False))

def filter_answers(ans: List[str|Dict[str, str]]) -> List[Dict[str, str]]:
    r"""Filter answers to ensure they are in the correct format"""
    def basic_checks(a1: Dict[str, str])->bool:
        # check required keys
        required_keys = ['answer']
        if all((key in a1) and isinstance(a1[key], str) for key in required_keys):
            if len(a1['answer']) == 1 and (a1['answer'] not in 'ABCDabcd'):
                    return False
            check_len = count_tokens_a(a1['answer'])
            if check_len < 50:
                check_len += count_tokens_a(a1.get('reasoning', 'None'))
                if check_len < 512:
                    # check answer format - EXTRA checks
                    # if len(a1['answer']) == 1 and a1['answer'].upper() in 'ABCD':
                    return True
        return False

    filtered_answers = []
    for i, a in enumerate(ans):
        if isinstance(a, dict):
            if basic_checks(a):
                filtered_answers.append(a)
            else:
                filtered_answers.append(None)
        elif isinstance(a, str):
            # Basic checks: at least with correct JSON format
            try:
                a1 = json.loads(a)
                if basic_checks(a1):
                    filtered_answers.append(a1)
                else:
                    filtered_answers.append(None)
            except json.JSONDecodeError:
                # If JSON decoding fails, skip this answer
                print(f"Skipping invalid JSON at index {i}: {a}")
                filtered_answers.append(None)
                continue
        else:
            # If the answer is neither a dict nor a str, skip it
            print(f"Skipping unsupported type at index {i}: {type(a)}")
            filtered_answers.append(None)
    return filtered_answers

# %%
with open("outputs/answers.json", "r") as f:
    answers = json.load(f)
filtered_answers = filter_answers(answers)


print(f"Number of answers: {len(answers)}")
print(f"Number of filtered answers: {len(filtered_answers)}")

# %% [markdown]
# ## Evaluation
# <!-- 🏅  -->

# %% [markdown]
# ### Scoring Criteria
#
# <!-- 📊  -->
#
# Scores are assigned based on: out of $N$ questions from Q-agent, how many an A-agent can answer and vice-versa. *No negative marking for wrong answers.*
#
# $$\text{A-agent Score} = \dfrac{\#\ \text{of questions correctly answered with expected format}}{N}\times 100$$
# $$\text{Q-agent Score} = \dfrac{\#\ \text{of questions incorrectly answered by A-agent}}{N}\times 100$$
#
#
# $N$ denotes the number of filtered / format-correct questions. **Teams whose Q-agent fails to generate at least $50\%$ of `num_questions` (where `num_questions` ranges from $2$ to $1000+$) of the questions correctly (as per [format-checking](#format-overview)) will be automatically disqualified.**<br>
#
# In case of **TIE**, closed benchmark questions will be used to evaluate the answer agents (A-agent) and rank the teams accordingly.

# %% [markdown]
# ### Scoring Example

# %%
# calculate scores...
N = len(filtered_questions)
assert N == len(filtered_answers), "Number of questions and answers must match."
num_correct_answers = len([1 for q,a in zip(filtered_questions, filtered_answers) if a is not None and q['answer'] == a['answer']])

# Here the answer may be correct, but since q['answer'] is not an option letter is not there, we face problems
# Below shown is one way of simple string parsing
num_correct_answers = len([1 for q,a in zip(filtered_questions, filtered_answers) if a is not None and q['answer'][0] == a['answer']])

a_score = num_correct_answers*100/(N+1e-9)
q_score = (N-num_correct_answers)*100/(N+1e-9)
# Announce the scores
print(f"Number of questions: {N}")
print(f"Number of correct answers: {num_correct_answers}")
print("Scores:")
print(f"Team B: A-agent score: {a_score:.2f}")
print(f"Team A: Q-agent score: {q_score:.2f}")
print(f"Innings 1 winner: {'Team A' if q_score > a_score else 'Team B' if q_score < a_score else 'Draw'}")
